# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav371/Python/blob/Module-4/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pyplot
mport matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([2,8])
ypoints=np.array([0,420])
plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([6, 8])
ypoints = np.array([6, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([6, 8])
ypoints = np.array([6, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([3, 5, 6, 8])
ypoints = np.array([3, 9, 7, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([1, 8, 3, 10, 6, 7])
plt.plot(ypoints)
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([1, 8, 1, 3])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([1, 8, 1, 3])
plt.plot(ypoints, marker = '*')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([9, 6, 9, 10])
plt.plot(ypoints, 'o:r')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 7, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 18)
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 12, 9])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 12, 9])
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 9, 13, 1])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 9, 13, 1])
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = 'r')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 9, 13, 1])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'pink', mfc = 'pink')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 6, 7, 10])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 6, 7, 10])
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 6, 7, 10])
plt.plot(ypoints, linestyle = ':')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 6, 7, 13])
plt.plot(ypoints, color = 'r')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 6, 7, 13])
plt.plot(ypoints, color = '#4CAF50')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 6, 7, 13])
plt.plot(ypoints, color = 'BLUE')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linewidth = '23')
plt.show()

# %%
#labels
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.plot(x, y)
plt.show()

# %%
#labels
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Title", fontdict = font1)
plt.xlabel("x", fontdict = font2)
plt.ylabel("y", fontdict = font2)
plt.plot(x, y)
plt.show()

# %%
#labels
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.plot(x, y)
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
#labels
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.title("title", loc = 'left')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.grid()
plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt
x = np.array([20, 75, 60, 45, 100, 105, 110, 135, 123, 127])
y = np.array([248, 250, 212, 241, 261, 290, 300, 313, 326, 330])
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([2, 8, 3, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([40, 30, 20, 10])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np
y=np.array([25,65,70,69])
plt.pie(y)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np
y=np.array([67,58,99,87])
labels=['apple','banana','kiwi','peach']
plt.pie(y,labels=labels,startangle=60)
plt.show()

# %%
#histogram
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(789,90,87)
plt.hist(x)
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#day one
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
#day two
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
#pie charts
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()
